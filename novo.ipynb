# %%
pip install requests

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\broth\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.12.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: soupsieve>1.2 in c:\users\broth\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from beautifulsoup4) (2.6)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\broth\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.magazineluiza.com.br/busca/geladeira/?from=submit'
headers={
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36",
        "cookie" : 'MLPARCEIRO=1957; noe_freight=AUTO; noe_hub_shipping_enabled=1; toggle_wishlist=false; FCCDCF=1; ml2_redirect_8020=0; FCNEC=1; mixer_shipping=AUTO; mixer_hub_shipping=true; toggle_pdp_seller_score=true; toggle_vwo=true; toggle_agatha=true; toggle_ads=true; toggle_new_service_page=true; toggle_search_ads=true; __spdt=e52d32ac2e724eacb459b9fd0adcfa74; __ssds=3; __rtbh.lid=%7B%22eventType%22%3A%22lid%22%2C%22id%22%3A%22mz97Mmo1GvI8awDCEeWx%22%7D; __ssuzjsr3=a9be0cd8e; __uzmaj3=b4e9a6d9-63dd-46f2-9254-1acc88967303; __uzmbj3=1725468707; _gcl_au=1.1.1531583586.1725468707; __gtm_campaign_url=https%3A%2F%2Fwww.magazineluiza.com.br%2F%3Futm_source%3Dbing%26utm_medium%3Dcpc%26utm_campaign%3Dbing_eco_per_ven_pes_none_sor_4p_branding%26partner_id%3D1957%26utm_term%3D1957%26%26gclid%3Dd7b4221228cd1c4e58f644cab8ed19ac%26gclsrc%3D3p.ds%26msclkid%3Dd7b4221228cd1c4e58f644cab8ed19ac%26gclid%3Dd7b4221228cd1c4e58f644cab8ed19ac%26gclsrc%3D3p.ds; __gtm_referrer=https%3A%2F%2Fwww.bing.com%2F; __ctodedup=other; _vwo_uuid_v2=DDEE72B4B2E2C5B6A8E46B8AA76A24E2B|be26059291e0ed4220dafe625042b2b8; _tt_enable_cookie=1; _ttp=7WQ_428J-cyBxeMM5zqOQ3eoWQi; _vwo_uuid=DDEE72B4B2E2C5B6A8E46B8AA76A24E2B; _vwo_ds=3%241725468707%3A69.08481964%3A%3A; _vis_opt_s=1%7C; _vis_opt_test_cookie=1; ml_tid=5119b50e-562a-4c0b-85af-f3b74d09b051; __bid=9080efab-1c97-4110-9a1a-53b468f0398f; __btgUtms=&utmSource=bing&utmMedium=cpc&utmCampaign=bing_eco_per_ven_pes_none_sor_4p_branding&utmTerm=1957; __rtbh.uid=%7B%22eventType%22%3A%22uid%22%2C%22id%22%3A%22unknown%22%7D; _fbp=fb.2.1725468708303.597493863403332150; _gcl_dc=GCL.1725468708.d7b4221228cd1c4e58f644cab8ed19ac; _hjSessionUser_4936838=eyJpZCI6Ijc3ZmUzYmJhLWJkYWMtNWIyYS1hYTk2LWI1MmVkODM2ZDMxMyIsImNyZWF0ZWQiOjE3MjU0Njg3MDg1NDEsImV4aXN0aW5nIjpmYWxzZX0=; _hjSession_4936838=eyJpZCI6IjgyMTlhNzIxLWUwMTctNDI2OC04YmZhLTZjNjM5OGMxZDk2OCIsImMiOjE3MjU0Njg3MDg1NDQsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MH0=; _pin_unauth=dWlkPU1qVXlZbU14TVRrdE5qQmlZUzAwWkRObUxUazVNRE10WTJKa1pERTBOMkl3T0RNMw; __uzma=af4c57b4-9a7a-4df3-8ee8-149901d70823; __uzmb=1725468708; __uzme=0876; stwu=temp_f9fb7e20-6add-11ef-acd2-570eac789e29; stwt=1; _gid=GA1.3.884707215.1725468709; _scid=8a1c3886-5247-48d5-a604-854941ba69d7; _clck=1bd3n4p%7C2%7Cfow%7C0%7C1708; _ScCbts=%5B%5D; __privaci_cookie_consent_uuid=7bf2ab6f-d2ff-4ee6-a3fc-33b4246d28f0:13; __privaci_cookie_consent_generated=7bf2ab6f-d2ff-4ee6-a3fc-33b4246d28f0:13; __privaci_cookie_consents={"consents":{"1":1,"2":1,"3":1,"4":1,"6":1},"location":"SP#BR","lang":"pt-br","gpcInBrowserOnConsent":false,"gpcStatusInPortalOnConsent":false,"status":"record-consent-success","implicit_consent":true}; __privaci_latest_published_version=9; cookie_reject_zipcode_popup=true; storedSessionIdLCJ5VBTH8V=1725468708; GTMUtmTimestamp=1725468712462; GTMUtmSource=bing; GTMUtmMedium=cpc; GTMUtmCampaign=bing_eco_per_ven_pes_none_sor_4p_branding; GTMUtmTerm=1957; GTMPartnerId=1957; GTMIsTrueDirect=0; search_attribution_token=null; _gat_UA-42817937-2=1; __uzmc=367572261889; __uzmd=1725469283; az_asm=l5XVClHGsM66xzwtRBJqxccpuBmEHAoSo/nfvDe0yqNwJk8D/VBVrydc4lov9r9Fg9J4eRenEzTMKF1e; az_botm=762d4fc955ecbbc592395efbd435fa9d; __uzmcj3=279501623751; __uzmdj3=1725469285; _ga_C98RVP2QRJ=GS1.1.1725468708.1.1.1725469289.38.0.0; _ga_LCJ5VBTH8V=GS1.1.1725468708.1.1.1725469289.38.0.0; _ga=GA1.3.1601075518.1725468708; _scid_r=8a1c3886-5247-48d5-a604-854941ba69d7; _uetsid=fa3607906add11efaca7c75631990ee5; _uetvid=fa3652c06add11efb2cde58a3bc45f17; _uetmsclkid=_uetd7b4221228cd1c4e58f644cab8ed19ac; _vwo_sn=0%3A4%3A%3A%3A1; cto_bundle=; _clsk=8gu3ri%7C1725469291483%7C4%7C0%7Cs.clarity.ms%2Fcollect'
    }

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="pt-br">
#  <head>
#   <link href="https://wx.mlcdn.com.br/site/shared/favicon/favicon-16x16.png" rel="shortcut icon"/>
#   <link href="https://wx.mlcdn.com.br/site/shared/favicon/favicon-96x96.png" rel="apple-touch-icon-precomposed" sizes="96x96"/>
#   <link href="https://wx.mlcdn.com.br/site/shared/favicon/favicon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <link href="https://wx.mlcdn.com.br/site/shared/favicon/favicon-57x57.png" rel="apple-touch-icon-precomposed"/>
#   <link href="https://wx.mlcdn.com.br/site/shared/favicon/favicon-16x16.png" rel="shortcut icon" type="image/ico"/>
#   <link crossorigin="true" defer="" href="https://6590300.fls.doubleclick.net" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://a-static.mlcdn.com.br" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://adservice.google.com.br" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://adservice.google.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://pixel.byspotify.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://analytics.tiktok.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://s1.kwai.net" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://bat.bing.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://c.mlcdn.com.br" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://cas.avalon.perfdrive.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://cdn.navdmp.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://cdn.perfdrive.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://cm.g.doubleclick.net" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://connect.facebook.net" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://ct.pinterest.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://device.4seeresults.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://dpm.demdex.net" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://googleads.g.doubleclick.net" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://gum.criteo.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://i.btg360.com.br" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://iosite.reclameaqui.com.br" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://mms-assets.magazineluiza.com.br" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://pagead2.googlesyndication.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://pixel.tapad.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://pubads.g.doubleclick.net" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://rgr.bob-recs" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://s.mlcdn.com.br" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://s.pinimg.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://s3.amazonaws.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://script.hotjar.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://sp.analytics.yahoo.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://static.hotjar.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://stats.g.doubleclick.net" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://vars.hotjar.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://vc.hotjar.io" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://www.google-analytics.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://www.google.com.br" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://www.google.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://www.googletagmanager.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://www.googletagservices.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://wx.mlcdn.com.br" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://magalu-ads-px.luizalabs.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://dev.visualwebsiteoptimizer.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://www.gstatic.com" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://static-magalu-ads.magazineluiza.com.br" rel="preconnect"/>
#   <link crossorigin="true" defer="" href="https://tags.creativecdn.com" rel="preconnect"/>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({originalLocation: document.location.protocol+'//'+
#     document.location.hostname+document.location.pathname+document.location.search});
#     w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-BR2N')
#   </script>
#   <script async="" fetchpriority="low" src="https://wx.mlcdn.com.br/site/shared/stewie/stewie-3.1.0.min.js">
#   </script>
#   <script defer="" fetchpriority="low" src="https://i.btg360.com.br/btg360-2.0.1.min.js">
#   </script>
#   <script defer="" fetchpriority="low" src="https://static.criteo.net/js/ld/ld.js">
#   </script>
#   <script>
#    !function (w, d, t) {
#     w.TiktokAnalyticsObject=t;var ttq=w[t]=w[t]||[];ttq.methods=["page","track","identify","instances","debug","on","off","once","ready","alias","group","enableCookie","disableCookie"],ttq.setAndDefer=function(t,e){t[e]=function(){t.push([e].concat(Array.prototype.slice.call(arguments,0)))}};for(var i=0;i<ttq.methods.length;i++)ttq.setAndDefer(ttq,ttq.methods[i]);ttq.instance=function(t){for(var e=ttq._i[t]||[],n=0;n<ttq.methods.length;n++)ttq.setAndDefer(e,ttq.methods[n]);return e},ttq.load=function(e,n){var i="https://analytics.tiktok.com/i18n/pixel/events.js";ttq._i=ttq._i||{},ttq._i[e]=[],ttq._i[e]._u=i,ttq._t=ttq._t||{},ttq._t[e]=+new Date,ttq._o=ttq._o||{},ttq._o[e]=n||{};var o=document.createElement("script");o.type="text/javascript",o.defer=true,o.fetchPriority="low",o.src=i+"?sdkid="+e+"&lib="+t;var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(o,a);};
#     ttq.load('C1I87V1T0U322RQPSRKG');
#     ttq.page();
#   }(window, document, 'ttq');
#   </script>
#   <script>
#    (function(w, d){
#     var id='spdt-capture', n='script';
#     if (!d.getElementById(id)) {
#       w.spdt =
#         w.spdt ||
#         function() {
#           (w.spdt.q = w.spdt.q || []).push(arguments);
#         };
#       var e = d.createElement(n); e.id = id; e.async=1;
#       e.src = 'https://pixel.byspotify.com/ping.min.js';
#       var s = d.getElementsByTagName(n)[0];
#       s.parentNode.insertBefore(e, s);
#     }
#     w.spdt('conf', { key: '66f417c2d2344c0980e19d4e7f996073' });
#   })(window, document);
#   </script>
#   <script id="radware">
#    (function (w, d, e, u, c, g, a, b) {
#         w['SSJSConnectorObj'] = w['SSJSConnectorObj'] || {
#           ss_cid: c,
#           domain_info: 'auto',
#         };
#         w[g] = function (i, j) {
#           w['SSJSConnectorObj'][i] = j;
#         };
#         a = d.createElement(e);
#         a.async = true;
#         a.fetchPriority = "low";
#         a.src = u;
#         b = d.getElementsByTagName(e)[0];
#         b.parentNode.insertBefore(a, b);
#       })(
#         window,
#         document,
#         'script',
#         'https://cdn.perfdrive.com/aperture/aperture.js',
#         'bna1',
#         'ssConf'
#       );
#       ssConf('c1', 'https://cas.avalon.perfdrive.com');
#   </script>
#   <script>
#    (function(d,c){var s=d.createElement('script');s.type='text/javascript';s.defer=!0;s.fetchPriority="low";s.src='https://static-magalu-ads.magazineluiza.com.br/sponsored-products-sdk/2.16.1/magalu-ads-events.js';s.onload=c;d.head.appendChild(s);})(document);
#   </script>
#   <script>
#    (function (w,d,dn,t){w[dn]=w[dn]||[];w[dn].push({eventType:'init',value:t,dc:'us'});
#       var f=d.getElementsByTagName('script')[0],
#       c=d.createElement('script');
#       c.async=true;
#       c.fetchPriority="low";
#       c.src='https://tags.creativecdn.com/msWukR4UlwKQouZSY8IT.js';
#       f.parentNode.insertBefore(c,f);})(window,document,'rtbhEvents','msWukR4UlwKQouZSY8IT');
#   </script>
#   <script>
#    window._vwo_code=window._vwo_code || (function() {
#         var account_id=752930,
#         version = 1.5,
#         settings_tolerance=2000,
#         library_tolerance=2500,
#         use_existing_jquery=false,
#         is_spa=1,
#         hide_element='body',
#         hide_element_style = '',
#         f=false,w=window,d=document,vwoCodeEl=d.querySelector('#vwoCode'),code={use_existing_jquery:function(){return use_existing_jquery},library_tolerance:function(){return library_tolerance},hide_element_style:function(){return'{'+hide_element_style+'}'},finish:function(){if(!f){f=true;var e=d.getElementById('_vis_opt_path_hides');if(e)e.parentNode.removeChild(e)}},finished:function(){return f},load:function(e){var t=d.createElement('script');t.fetchPriority='low';t.src=e;t.type='text/javascript';t.onerror=function(){_vwo_code.finish()};d.getElementsByTagName('head')[0].appendChild(t)},getVersion:function(){return version},getMatchedCookies:function(e){var t=[];if(document.cookie){t=document.cookie.match(e)||[]}return t},getCombinationCookie:function(){var e=code.getMatchedCookies(/(?:^|;)\s?(_vis_opt_exp_\d+_combi=[^;$]*)/gi);e=e.map(function(e){try{var t=decodeURIComponent(e);if(!/_vis_opt_exp_\d+_combi=(?:\d+,?)+\s*$/.test(t)){return''}return t}catch(e){return''}});var i=[];e.forEach(function(e){var t=e.match(/([\d,]+)/g);t&&i.push(t.join('-'))});return i.join('|')},init:function(){if(d.URL.indexOf('__vwo_disable__')>-1)return;w.settings_timer=setTimeout(function(){_vwo_code.finish()},settings_tolerance);var e=d.currentScript,t=d.createElement('style'),i=e&&!e.async?hide_element?hide_element+'{'+hide_element_style+'}':'':code.lA=1,n=d.getElementsByTagName('head')[0];t.setAttribute('id','_vis_opt_path_hides');vwoCodeEl&&t.setAttribute('nonce',vwoCodeEl.nonce);t.setAttribute('type','text/css');if(t.styleSheet)t.styleSheet.cssText=i;else t.appendChild(d.createTextNode(i));n.appendChild(t);var o=this.getCombinationCookie();this.load('https://dev.visualwebsiteoptimizer.com/j.php?a='+account_id+'&u='+encodeURIComponent(d.URL)+'&f='+ +is_spa+'&vn='+version+(o?'&c='+o:''));return settings_timer}};w._vwo_settings_timer = code.init();return code;}());
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0 maximum-scale=1.0" name="viewport"/>
#   <link data-testid="link-0" href="https://www.magazineluiza.com.br/busca/geladeira/?from=submit" rel="canonical"/>
#   <link data-testid="link-1" href="https://m.magazineluiza.com.br/busca/geladeira/?from=submit" media="only screen and (max-width: 640px)" rel="alternate"/>
#   <title data-testid="meta-title">
#    Geladeira Em Promoção | Magazine Luiza
#   </title>
#   <meta content="Geladeiras em Promoção no Magalu! Escolha entre diversos modelos e marcas. Geladeira Eletrolux, Bratemp, Consul e mais. Escolha a sua com preço baixo e entrega garantida!" data-testid="meta-description" name="description"/>
#   <meta content="18" name="next-head-count"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script defer="" nomodule="" src="/mixer/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/webpack-89ee4f872d9123e4.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/framework-a78051e383c5165f.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/main-babd0d31cb19eb15.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/pages/_app-1b6f7666ba993df1.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/2edb282b-5e499321bfa6e8ba.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/e893f787-2ae0bfd75891c79c.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/9601-808c40fa11b1b2f4.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/7833-719f44f2063f3dac.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/651-ea9638c83be249fa.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/5040-9075bc2ed8460701.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/4598-e581269211674b77.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/8035-498e03d8d2b90a2d.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/6473-2af91431c8c028b0.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/8914-f68b104ddbfa893e.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/4519-aa95ed4b97496010.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/2071-c5b6713c5f832454.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/1782-48647af971e4d51a.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/4490-9ff9cd1df7ee5d85.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/5449-89cd956d52e663c1.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/2635-a3d26a26d09cc1d1.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/7867-002bb1ebed36119b.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/6576-c2e8a0d35602c527.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/457-090955a9c92bb5c9.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/3371-f340c2f282169a40.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/1049-6c010aeb28fb0c89.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/7043-3ed85803cdc561a3.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/9653-ceac90eaa47bc785.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/6567-5489c85a56e5d126.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/6515-6ba9c2183f5be64b.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/8125-c63b9e5d967c0874.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/2768-d138af6328992e6c.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/9731-0534114173a83f8c.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/214-60a0d5de71e1f369.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/6700-da3a31624d3c53c6.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/1105-bfd0737276f064c6.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/5328-6bf4c01b56b5f39f.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/2898-eebdee1e790e60c7.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/4449-3d17fb525c805270.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/9742-8a6ef6d7414e4473.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/2571-3f14e7b75d9b4b40.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/1948-4135131f320d6ec6.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/9434-458631882d03982b.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/4685-d3bd145ab5b88f95.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/8354-7ee99d0a91e86729.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/1765-07ab9555c4a5e877.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/2271-f4bea392ac17d4ef.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/5318-fb6e3b92080638fc.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/4172-03869bb555e03b16.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/7890-03c644396f9e0ecf.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/3912-b92c31791adc1bd0.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/2169-eb898ae219e51fc8.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/9592-e3148026a18156f1.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/365-b39c9e5cb8fccda4.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/2760-bf76d61b224c5db4.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/97-9e7e5abadf3b1a9d.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/9509-84639f29c8f0f0cd.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/8091-b6b2190bfb6e3733.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/142-3c5be4e17e8d42b6.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/chunks/pages/busca/%5Bpath1%5D-cd471a3db8d61f3d.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/xA3bfBTxVZIga3FevRJem/_buildManifest.js">
#   </script>
#   <script defer="" src="/mixer/_next/static/xA3bfBTxVZIga3FevRJem/_ssgManifest.js">
#   </script>
#   <style data-styled="" data-styled-version="5.3.11">
#    .gyuetJ{font-family:'Roboto',sans-serif;line-height:14px;font-weight:400;}/*!sc*/
# .gyuetJ *{margin:0;padding:0;outline:0;box-sizing:border-box;}/*!sc*/
# .gyuetJ body{margin:0;}/*!sc*/
# data-styled.g1[id="sc-aXZVg"]{content:"gyuetJ,"}/*!sc*/
# .gCFhJd{visibility:hidden;position:fixed;z-index:-1;}/*!sc*/
# data-styled.g2[id="sc-gEvEer"]{content:"gCFhJd,"}/*!sc*/
# .lfQClK{width:95;height:113;}/*!sc*/
# .cBGsfW{color:#fff;fill:#fff;width:138px;height:30px;}/*!sc*/
# .IubVJ{width:24px;height:24px;}/*!sc*/
# .jNEFZi{color:#fefefe;fill:#fefefe;}/*!sc*/
# .ldawGH{color:#ffffff;fill:#ffffff;width:29px;height:25px;}/*!sc*/
# .krSvRH{color:#818181;fill:#818181;width:24px;height:24px;}/*!sc*/
# .iPKphr{color:#0086ff;fill:#0086ff;width:40px;height:40px;}/*!sc*/
# .kmTCMh{width:20px;height:20px;}/*!sc*/
# .uYRDz{color:transparent;fill:transparent;width:20px;height:20px;}/*!sc*/
# .jmfCXY{color:#ccc;fill:#ccc;width:30px;height:30px;cursor:not-allowed;}/*!sc*/
# .euvVFb{color:#333;fill:#333;width:30px;height:30px;cursor:pointer;}/*!sc*/
# .gDBKFH{color:currentColor;fill:currentColor;width:24px;height:24px;}/*!sc*/
# data-styled.g3[id="sc-eqUAAy"]{content:"lfQClK,cBGsfW,IubVJ,jNEFZi,ldawGH,krSvRH,iPKphr,kmTCMh,uYRDz,jmfCXY,euvVFb,gDBKFH,"}/*!sc*/
# .gMwfBJ{box-sizing:border-box;cursor:inherit;background-color:#eee;width:100%;height:75px;padding-top:44px;overflow:hidden;color:#010101;}/*!sc*/
# .hlqElk{box-sizing:border-box;cursor:inherit;}/*!sc*/
# .aBptt{box-sizing:border-box;cursor:inherit;color:white;font-weight:700;font-size:12px;color:white;}/*!sc*/
# .cthyNi{box-sizing:border-box;cursor:inherit;background-color:#eee;width:100%;height:75px;padding-top:161%;overflow:hidden;color:#010101;}/*!sc*/
# .hvgPpT{box-sizing:border-box;cursor:inherit;background-color:#eee;width:100%;height:75px;padding-top:83%;overflow:hidden;color:#010101;}/*!sc*/
# .NYBqe{box-sizing:border-box;cursor:inherit;background-color:#eee;width:100%;height:75px;padding-top:6%;overflow:hidden;color:#010101;}/*!sc*/
# .brzqJX{box-sizing:border-box;cursor:inherit;text-align:justify;font-size:14px;color:#808080;font-weight:400;line-height:1.25;color:#808080;}/*!sc*/
# .faTyFi{box-sizing:border-box;cursor:inherit;margin-bottom:16px;}/*!sc*/
# .gWCWCP{box-sizing:border-box;cursor:inherit;margin-top:16px;margin-bottom:16px;margin-left:8px;margin-right:8px;}/*!sc*/
# .kkqFvN{box-sizing:border-box;cursor:inherit;border-radius:4px;z-index:1;}/*!sc*/
# .bZUYPY{box-sizing:border-box;cursor:inherit;background-color:#0086ff;border-radius:4px;z-index:10;color:#ffffff;}/*!sc*/
# .dLWaZk{box-sizing:border-box;cursor:inherit;width:20%;}/*!sc*/
# .sPxxI{box-sizing:border-box;cursor:inherit;box-shadow:0px 2px 12px rgba(81,81,81,0.12);border-radius:4px;}/*!sc*/
# @media screen and (min-width:48em){.sPxxI{box-shadow:0px 2px 12px rgba(81,81,81,0.12);}}/*!sc*/
# @media screen and (min-width:64em){.sPxxI{box-shadow:unset;}}/*!sc*/
# @media screen and (min-width:72em){.sPxxI{box-shadow:unset;}}/*!sc*/
# .dzACBc{box-sizing:border-box;cursor:inherit;font-size:18px;line-height:1;}/*!sc*/
# @media screen and (min-width:48em){.dzACBc{font-size:24px;}}/*!sc*/
# .keRZJx{box-sizing:border-box;cursor:inherit;margin-top:4px;}/*!sc*/
# .krxkdV{box-sizing:border-box;cursor:inherit;min-height:480px;}/*!sc*/
# .kuaEOu{box-sizing:border-box;cursor:inherit;margin:8px;border-top-width:1px;border-top-color:#e5e5e5;border-top-style:solid;}/*!sc*/
# .fGzoDM{box-sizing:border-box;cursor:inherit;font-size:16px;line-height:1.3em;}/*!sc*/
# .dkvYmG{box-sizing:border-box;cursor:inherit;margin-top:16px;}/*!sc*/
# .owGVz{box-sizing:border-box;cursor:inherit;text-align:center;margin-bottom:32px;}/*!sc*/
# data-styled.g4[id="sc-fqkvVR"]{content:"gMwfBJ,hlqElk,aBptt,cthyNi,hvgPpT,NYBqe,brzqJX,faTyFi,gWCWCP,kkqFvN,bZUYPY,dLWaZk,sPxxI,dzACBc,keRZJx,krxkdV,kuaEOu,fGzoDM,dkvYmG,owGVz,"}/*!sc*/
# .btfYoW{width:100%;min-height:100vh;display:grid;grid-template-columns:1fr minmax(auto,366px) minmax(auto,1000px) 1fr;grid-template-rows:auto auto auto auto auto auto auto;grid-template-areas:'header header header header' '. beforecontent beforecontent .' '. sideleft content .' '. aftercontent aftercontent .' 'footer footer footer footer';background-color:#fff;}/*!sc*/
# data-styled.g5[id="sc-f0cf7f7-0"]{content:"btfYoW,"}/*!sc*/
# @font-face{font-display:swap;font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto'),local('Roboto-Regular'),url('/mixer/assets/fonts/roboto-v20-latin-regular.woff2') format('woff2'),url('/mixer/assets/fonts/roboto-v20-latin-regular.woff') format('woff');}/*!sc*/
# @font-face{font-display:swap;font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url('/mixer/assets/fonts/roboto-v20-latin-500.woff2') format('woff2'),url('/mixer/assets/fonts/roboto-v20-latin-500.woff') format('woff');}/*!sc*/
# @font-face{font-display:swap;font-family:'Roboto';font-style:normal;font-weight:700;src:local('Roboto Bold'),local('Roboto-Bold'),url('/mixer/assets/fonts/roboto-v20-latin-700.woff2') format('woff2'),url('/mixer/assets/fonts/roboto-v20-latin-700.woff') format('woff');}/*!sc*/
# html,body{margin:unset;background-color:#f4f4f4;color:#404040;font-family:'Roboto',sans-serif;}/*!sc*/
# ol,ul{list-style:none;}/*!sc*/
# *,*:before,*:after{box-sizing:border-box;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# body{position:relative;}/*!sc*/
# a:hover{border:0px solid transparent;}/*!sc*/
# a:focus{border:0px solid transparent;}/*!sc*/
# a:focus-visible{outline:auto 1px Highlight;outline:auto 1px -webkit-focus-ring-color;}/*!sc*/
# data-styled.g6[id="sc-global-kctvkb1"]{content:"sc-global-kctvkb1,"}/*!sc*/
# .eFPLPU{margin:0px;max-height:44px;}/*!sc*/
# .cOvOQL{line-height:normal;padding:9px 14px;text-align:left;margin-top:30px;}/*!sc*/
# .bGerwH{line-height:normal;padding:9px 14px;text-align:left;margin-bottom:30px;}/*!sc*/
# .hmLryf{margin:8px;}/*!sc*/
# .izaRHP{margin-bottom:20px;}/*!sc*/
# .ijOYDy{margin:40px 20px;padding:16px;}/*!sc*/
# data-styled.g7[id="sc-dcJsrY"]{content:"eFPLPU,cOvOQL,bGerwH,hmLryf,izaRHP,ijOYDy,"}/*!sc*/
# .gmoNnh{position:relative;cursor:pointer;}/*!sc*/
# .gmoNnh div,.gmoNnh iframe{position:absolute;top:0;left:0;width:100% !important;height:100% !important;}/*!sc*/
# data-styled.g8[id="sc-iGgWBj"]{content:"gmoNnh,"}/*!sc*/
# .ega-dLX{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background-color:#fff;}/*!sc*/
# .cFngep{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .hFfCHu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#fefefe;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;font-size:12px;font-weight:normal;}/*!sc*/
# @media screen and (min-width:48em){.hFfCHu{-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}/*!sc*/
# @media screen and (min-width:64em){.hFfCHu{-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}/*!sc*/
# .bnbGnK{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:2px;margin-right:2px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .btnvKH{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;color:#0086ff;margin:0;}/*!sc*/
# .knkpxB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-bottom:8px;margin-top:8px;cursor:pointer;padding-top:0;padding-bottom:0;width:100%;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;padding-left:8px;padding-right:8px;gap:0;}/*!sc*/
# .lamXqB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding-left:0;padding-right:0;padding-top:0;padding-bottom:0;width:100%;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;gap:8px;}/*!sc*/
# .edNolM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .ktOaID{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;text-align:initial;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;position:relative;padding-left:0;padding-right:0;padding-top:0;padding-bottom:0;width:100%;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;gap:0;row-gap:8px;}/*!sc*/
# .cOyvbJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;position:relative;padding-left:0;padding-right:0;padding-top:0;padding-bottom:0;width:100%;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;gap:0;row-gap:8px;}/*!sc*/
# .iHhpRL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:32px;}/*!sc*/
# .ikmMqH{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;font-weight:500;position:relative;padding-left:0;padding-right:0;padding-top:0;padding-bottom:0;width:100%;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;gap:4px;row-gap:8px;}/*!sc*/
# .jSVrRq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;gap:4px;}/*!sc*/
# .fXVwaj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;background-color:#fff;}/*!sc*/
# .huhLxr{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;font-weight:500;position:relative;padding-left:0;padding-right:0;padding-top:0;padding-bottom:0;width:100%;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;gap:0;row-gap:8px;}/*!sc*/
# .iqlXfT{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:32px;}/*!sc*/
# .bOgnHP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;}/*!sc*/
# .bnJJCu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-content:space-between;-ms-flex-line-pack:space-between;align-content:space-between;}/*!sc*/
# .qVBcJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;row-gap:16px;}/*!sc*/
# .lgpKMJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-column-gap:8px;column-gap:8px;row-gap:8px;}/*!sc*/
# @media screen and (min-width:48em){.lgpKMJ{-webkit-column-gap:16px;column-gap:16px;}}/*!sc*/
# .ryZxx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g13[id="sc-dhKdcB"]{content:"ega-dLX,cFngep,hFfCHu,bnbGnK,btnvKH,knkpxB,lamXqB,edNolM,ktOaID,cOyvbJ,iHhpRL,ikmMqH,jSVrRq,fXVwaj,huhLxr,iqlXfT,bOgnHP,bnJJCu,qVBcJ,lgpKMJ,ryZxx,"}/*!sc*/
# .eganTk{-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-flex:1;-ms-flex:1;flex:1;color:inherit;position:initial;left:initial;-webkit-transform:initial;-ms-transform:initial;transform:initial;}/*!sc*/
# .SqDpH{font-size:16px;font-weight:500;color:#404040;}/*!sc*/
# .fZjxQr{font-size:16px;text-align:initial;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-flex:1;-ms-flex:1;flex:1;color:inherit;position:initial;left:initial;-webkit-transform:initial;-ms-transform:initial;transform:initial;}/*!sc*/
# .dMmAEZ{font-size:16px;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-flex:1;-ms-flex:1;flex:1;color:inherit;position:initial;left:initial;-webkit-transform:initial;-ms-transform:initial;transform:initial;}/*!sc*/
# .giawfp{font-size:12px;color:#404040;}/*!sc*/
# .lnjnuG{color:inherit;}/*!sc*/
# .hsdGBD{font-size:18px;color:#515151;}/*!sc*/
# .eCPtRw{color:#404040;}/*!sc*/
# .cQXUXR{color:#404040;font-size:24px;font-weight:700;padding-right:4px;}/*!sc*/
# .kOucWw{color:#404040;font-size:24px;}/*!sc*/
# .efxPhd{font-size:12px;line-height:1;color:#808080;}/*!sc*/
# @media screen and (min-width:48em){.efxPhd{font-size:14px;}}/*!sc*/
# .cZTiGu{margin-top:8px;font-size:12px;font-weight:400;line-height:1;color:#404040;}/*!sc*/
# @media screen and (min-width:48em){.cZTiGu{font-size:14px;line-height:1.25;}}/*!sc*/
# data-styled.g14[id="sc-kpDqfm"]{content:"eganTk,SqDpH,fZjxQr,dMmAEZ,giawfp,lnjnuG,hsdGBD,eCPtRw,cQXUXR,kOucWw,efxPhd,cZTiGu,"}/*!sc*/
# .ehGUhH{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .hhvuzR{-webkit-text-decoration:none;text-decoration:none;min-height:56px;}/*!sc*/
# .bxjiaF{-webkit-text-decoration:none;text-decoration:none;color:#404040;background-color:transparent;min-height:32px;}/*!sc*/
# .hFmSFR{-webkit-text-decoration:none;text-decoration:none;color:#404040;background-color:#ffffff;min-height:48px;}/*!sc*/
# .pYlMs{-webkit-text-decoration:none;text-decoration:none;color:#404040;background-color:#ffffff;min-height:32px;}/*!sc*/
# data-styled.g23[id="sc-fPXMVe"]{content:"ehGUhH,hhvuzR,bxjiaF,hFmSFR,pYlMs,"}/*!sc*/
# .gtqEvS{-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;text-align:justify;text-align-last:left;}/*!sc*/
# data-styled.g25[id="sc-ikkxIA"]{content:"gtqEvS,"}/*!sc*/
# .eoEyLc{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;padding-right:8px;}/*!sc*/
# data-styled.g27[id="sc-feUZmu"]{content:"eoEyLc,"}/*!sc*/
# .eCopNl{overflow:hidden;-webkit-transition:max-height 0.3s ease-out;transition:max-height 0.3s ease-out;max-height:100%;}/*!sc*/
# .hepyHx{overflow:hidden;-webkit-transition:max-height 0.3s ease-out;transition:max-height 0.3s ease-out;max-height:0px;}/*!sc*/
# data-styled.g28[id="sc-fUnMCh"]{content:"eCopNl,hepyHx,"}/*!sc*/
# .LYIQn{display:grid;grid-template-columns:repeat(auto-fit,minmax(30px,max-content));-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:8px;grid-gap:32px;}/*!sc*/
# data-styled.g29[id="sc-hzhJZQ"]{content:"LYIQn,"}/*!sc*/
# .lnydW{position:relative;width:100%;height:100%;border:none;cursor:pointer;background:none;-webkit-transition:all 0.2s ease-in-out;transition:all 0.2s ease-in-out;}/*!sc*/
# .lnydW:disabled{opacity:0.5;}/*!sc*/
# .lnydW:hover:not(:disabled){-webkit-transform:scale(1.1);-ms-transform:scale(1.1);transform:scale(1.1);}/*!sc*/
# data-styled.g30[id="sc-fHjqPf"]{content:"lnydW,"}/*!sc*/
# .cDaSDB{cursor:not-allowed;font-weight:500;text-align:center;margin-top:1px;grid-area:label;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;}/*!sc*/
# .cDaSDB small{font-weight:500;text-transform:none;display:block;}/*!sc*/
# data-styled.g40[id="sc-dtInlm"]{content:"cDaSDB,"}/*!sc*/
# .cxfMbY{cursor:not-allowed;font-family:'Roboto',sans-serif;outline:none;border:none;border-radius:4px;padding:0px 15px;width:100%;display:grid;grid-column:unset;grid-template-areas:'label';grid-template-columns:auto;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-text-decoration:none;text-decoration:none;height:44px;min-width:140px;font-size:14px;background-color: #0086ff;color:#fefefe;width:medium;height:medium;}/*!sc*/
# .cxfMbY .sc-dtInlm{text-transform:uppercase;}/*!sc*/
# .cxfMbY svg{fill:#fefefe;}/*!sc*/
# .cxfMbY:hover{background-color: #005eb2;color:#fefefe;}/*!sc*/
# .cxfMbY,.cxfMbY:hover{background-color:#e5e5e5;color:#808080;}/*!sc*/
# .cxfMbY svg,.cxfMbY:hover svg{fill:#808080;}/*!sc*/
# data-styled.g42[id="sc-cWSHoV"]{content:"cxfMbY,"}/*!sc*/
# .iKZqua{width:100%;height:inherit;object-fit:contain;}/*!sc*/
# .gVeHJL{width:100%;height:inherit;object-fit:contain;margin-bottom:4px;}/*!sc*/
# .bzVpXq{width:100%;height:inherit;object-fit:contain;border-radius:4px;}/*!sc*/
# .igquRA{width:100%;height:inherit;object-fit:contain;max-height:90px;}/*!sc*/
# .OGWcq{width:100%;height:inherit;object-fit:contain;max-height:25px;}/*!sc*/
# .ggDvke{width:100%;height:inherit;object-fit:contain;max-height:12px;}/*!sc*/
# data-styled.g43[id="sc-eBMEME"]{content:"iKZqua,gVeHJL,bzVpXq,igquRA,OGWcq,ggDvke,"}/*!sc*/
# .klIJqU{-webkit-transition:box-shadow ease 0.4s;transition:box-shadow ease 0.4s;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;display:grid;overflow:hidden;grid-template-areas:"image" "body";-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;border-radius:6px;}/*!sc*/
# .klIJqU:hover{box-shadow:0px 2px 12px rgba(81,81,81,0.12);}/*!sc*/
# data-styled.g44[id="sc-dCFHLb"]{content:"klIJqU,"}/*!sc*/
# .drDzgT{-webkit-appearance:none;-moz-appearance:none;appearance:none;background:transparent;width:20px;height:20px;outline:none;cursor:pointer;}/*!sc*/
# .drDzgT:not(:checked){border-radius:4px;border:2px solid #bcbcbc;}/*!sc*/
# .drDzgT:checked:after{content:url('...');position:absolute;width:20px;height:20px;background:#0086ff;border-radius:4px;box-sizing:border-box;}/*!sc*/
# .drDzgT:checked:disabled:after{background:#999;}/*!sc*/
# data-styled.g51[id="sc-fXSgeo"]{content:"drDzgT,"}/*!sc*/
# .fPvMCy{width:125px;min-width:144px;max-width:144px;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# data-styled.g52[id="sc-JrDLc"]{content:"fPvMCy,"}/*!sc*/
# .kpfePJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border:none;-webkit-scroll-snap-align:center;-moz-scroll-snap-align:center;-ms-scroll-snap-align:center;scroll-snap-align:center;border-radius:32px;min-width:144px;height:38px;-webkit-transition:all 500ms ease;-webkit-transition:all 500ms ease;transition:all 500ms ease;background-color:#0086ff;color:#ffffff;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;width:auto;min-width:auto;height:auto;padding:8px 8px;-webkit-transition:all 500ms ease;-webkit-transition:all 500ms ease;transition:all 500ms ease;-moz-user-select:-moz-none;-webkit-user-select:none;-ms-user-select:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-transition:all 500ms ease;-webkit-transition:all 500ms ease;transition:all 500ms ease;border-radius:6px;padding:2px 8px;font-size:14px;font-weight:500;grid-gap:4px;}/*!sc*/
# .kpfePJ > svg{-webkit-transition:all 500ms ease;-webkit-transition:all 500ms ease;transition:all 500ms ease;fill:#ffffff;}/*!sc*/
# data-styled.g53[id="sc-fjvvzt"]{content:"kpfePJ,"}/*!sc*/
# .bSunpA{max-width:60%;font-size:inherit;font-weight:inherit;line-height:14px;font-stretch:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;max-width:100%;}/*!sc*/
# data-styled.g54[id="sc-bbSZdi"]{content:"bSunpA,"}/*!sc*/
# .RHqaG{display:grid;}/*!sc*/
# .jBFBmG{display:grid;margin-top:16px;margin-bottom:16px;margin-left:8px;margin-right:8px;row-gap:16px;}/*!sc*/
# .pPFnt{display:grid;gap:8px;}/*!sc*/
# data-styled.g56[id="sc-hknOHE"]{content:"RHqaG,jBFBmG,pPFnt,"}/*!sc*/
# .eHhhTu{display:grid;}/*!sc*/
# .eHhhTu > *:nth-child(n + 6){display:none;overflow:hidden;max-height:0;}/*!sc*/
# data-styled.g57[id="sc-uVWWZ"]{content:"eHhhTu,"}/*!sc*/
# .iZCfsc{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;color:#404040;font-size:14px;}/*!sc*/
# .iZCfsc:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#404040;}/*!sc*/
# .cfqWTd{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;color:#404040;margin-right:16px;font-size:14px;}/*!sc*/
# .cfqWTd:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#404040;}/*!sc*/
# .kSwDbq{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#cce6f4;background-color:transparent;padding:0;font-size:12px;font-weight:700;}/*!sc*/
# .kSwDbq:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#cce6f4;}/*!sc*/
# @media screen and (min-width:48em){.kSwDbq{font-size:12px;font-weight:700;}}/*!sc*/
# @media screen and (min-width:64em){.kSwDbq{font-size:12px;font-weight:700;}}/*!sc*/
# @media screen and (min-width:72em){.kSwDbq{font-size:14px;font-weight:400;}}/*!sc*/
# .iZlyRG{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:white;background-color:transparent;padding:0;font-size:12px;}/*!sc*/
# .iZlyRG:hover{-webkit-text-decoration:underline;text-decoration:underline;color:white;}/*!sc*/
# .eddHir{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;color:#404040;margin-left:4px;margin-right:4px;font-size:14px;}/*!sc*/
# .eddHir:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#404040;}/*!sc*/
# .cbJCLP{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#ffffff;background-color:transparent;padding-left:10px;padding-right:10px;font-size:14px;}/*!sc*/
# .cbJCLP:hover{-webkit-text-decoration:none;text-decoration:none;color:#ffffff;}/*!sc*/
# .dDlhdv{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;color:#404040;padding-left:8px;padding-right:8px;font-size:14px;}/*!sc*/
# .dDlhdv:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#404040;}/*!sc*/
# .fFcYoc{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#a400e1;background-color:transparent;font-size:14px;}/*!sc*/
# .fFcYoc:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#a400e1;}/*!sc*/
# .dkXWzM{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#ff8a00;background-color:transparent;font-size:14px;}/*!sc*/
# .dkXWzM:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#ff8a00;}/*!sc*/
# .jYawSk{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#00d604;background-color:transparent;font-size:14px;}/*!sc*/
# .jYawSk:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#00d604;}/*!sc*/
# .daXDQF{cursor:pointer;font-size:inherit;font-family:inherit;border:0;margin:0;overflow:visible;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#0086ff;background-color:transparent;padding-left:0;padding-right:0;font-weight:500;font-size:16px;}/*!sc*/
# .daXDQF:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#0086ff;}/*!sc*/
# .bXWMzg{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#fefefe;background-color:transparent;padding:0;font-size:14px;}/*!sc*/
# .bXWMzg:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#fefefe;}/*!sc*/
# .cfPxOX{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#fefefe;background-color:transparent;padding-left:10px;padding-right:10px;font-size:14px;}/*!sc*/
# .cfPxOX:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#fefefe;}/*!sc*/
# .hRfPXC{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#fefefe;background-color:transparent;padding:0;padding-left:4px;font-size:14px;}/*!sc*/
# .hRfPXC:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#fefefe;}/*!sc*/
# .hzvCPm{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#fefefe;background-color:transparent;padding-left:4px;font-size:14px;}/*!sc*/
# .hzvCPm:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#fefefe;}/*!sc*/
# data-styled.g58[id="sc-hCPjZK"]{content:"iZCfsc,cfqWTd,kSwDbq,iZlyRG,eddHir,cbJCLP,dDlhdv,fFcYoc,dkXWzM,jYawSk,daXDQF,bXWMzg,cfPxOX,hRfPXC,hzvCPm,"}/*!sc*/
# .dwTIwG{height:1px;width:100%;border:none;background-color:#ececec;}/*!sc*/
# data-styled.g66[id="sc-bypJrT"]{content:"dwTIwG,"}/*!sc*/
# .ewbmFd{border:1px solid;border-color:#ececec;border-radius:4px;width:100%;padding:8px;line-height:1.4;font-size:14px;}/*!sc*/
# .ewbmFd::-webkit-input-placeholder{color:#999;}/*!sc*/
# .ewbmFd::-moz-placeholder{color:#999;}/*!sc*/
# .ewbmFd:-ms-input-placeholder{color:#999;}/*!sc*/
# .ewbmFd::placeholder{color:#999;}/*!sc*/
# data-styled.g74[id="sc-ggpjZQ"]{content:"ewbmFd,"}/*!sc*/
# .kqKWQz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;}/*!sc*/
# .kqKWQz label{margin-right:10px;font-weight:700;font-size:12px;}/*!sc*/
# .kqKWQz select{-webkit-appearance:none;-moz-appearance:none;appearance:none;display:block;background:transparent;cursor:pointer;border:1px solid #bcbcbc;font-size:12px;padding:8px 32px 8px 12px;}/*!sc*/
# .kqKWQz select:focus{outline:none;background:#f4f4f4;}/*!sc*/
# .kqKWQz select::-ms-expand{display:none;}/*!sc*/
# .kqKWQz svg{outline:none;pointer-events:none;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;margin-left:-32px;}/*!sc*/
# data-styled.g83[id="sc-jMakVo"]{content:"kqKWQz,"}/*!sc*/
# .eplOlf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:100%;height:100%;}/*!sc*/
# data-styled.g84[id="sc-iMTnTL"]{content:"eplOlf,"}/*!sc*/
# .ktfvmK{position:relative;width:100%;height:100%;max-width:60px;max-height:46px;border:none;cursor:pointer;background:none;-webkit-transition:all 0.2s ease-in-out;transition:all 0.2s ease-in-out;}/*!sc*/
# .ktfvmK:disabled{opacity:0.5;}/*!sc*/
# ...
#                parcerias
#               </p>
#               <ul class="sc-ctLLLr NIBoy">
#                <li class="sc-gPDKlO gLLcWv">
#                 <a class="sc-hCPjZK cfPxOX sc-xyOoZ fREXsT sc-xyOoZ fREXsT" color="text.lightest" data-testid="link-item" font-size="1" href="https://www.magazineluiza.com.br/parcerias/" title="Link para: Parcerias">
#                  <span class="sc-dqJYEZ kDyRHs">
#                   <div class="sc-hMBXfw dsToUA">
#                    seja nosso parceiro
#                   </div>
#                  </span>
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div data-testid="link-section">
#               <p class="sc-kuCHnY irIKRI" color="text.lightest" font-size="1" font-weight="regular">
#                institucional
#               </p>
#               <ul class="sc-ctLLLr NIBoy">
#                <li class="sc-gPDKlO gLLcWv">
#                 <a class="sc-hCPjZK cfPxOX sc-xyOoZ fREXsT sc-xyOoZ fREXsT" color="text.lightest" data-testid="link-item" font-size="1" href="https://ri.magazineluiza.com.br/show.aspx?idCanal=urUqu4hANldyCLgMRgOsTw==" title="Link para: Quem somos">
#                  <span class="sc-dqJYEZ kDyRHs">
#                   <div class="sc-hMBXfw dsToUA">
#                    quem somos
#                   </div>
#                  </span>
#                 </a>
#                </li>
#                <li class="sc-gPDKlO gLLcWv">
#                 <a class="sc-hCPjZK cfPxOX sc-xyOoZ fREXsT sc-xyOoZ fREXsT" color="text.lightest" data-testid="link-item" font-size="1" href="https://lojas.magazineluiza.com.br/" title="Link para: Nossas lojas">
#                  <span class="sc-dqJYEZ kDyRHs">
#                   <div class="sc-hMBXfw dsToUA">
#                    nossas lojas
#                   </div>
#                  </span>
#                 </a>
#                </li>
#                <li class="sc-gPDKlO gLLcWv">
#                 <a class="sc-hCPjZK cfPxOX sc-xyOoZ fREXsT sc-xyOoZ fREXsT" color="text.lightest" data-testid="link-item" font-size="1" href="https://www.magazineluiza.com.br/blog-da-lu/" title="Link para: Blog da Lu">
#                  <span class="sc-dqJYEZ kDyRHs">
#                   <div class="sc-hMBXfw dsToUA">
#                    blog da Lu
#                   </div>
#                  </span>
#                 </a>
#                </li>
#                <li class="sc-gPDKlO gLLcWv">
#                 <a class="sc-hCPjZK cfPxOX sc-xyOoZ fREXsT sc-xyOoZ fREXsT" color="text.lightest" data-testid="link-item" font-size="1" href="https://carreiras.magazineluiza.com.br" title="Link para: Trabalhe conosco">
#                  <span class="sc-dqJYEZ kDyRHs">
#                   <div class="sc-hMBXfw dsToUA">
#                    trabalhe conosco
#                   </div>
#                  </span>
#                 </a>
#                </li>
#                <li class="sc-gPDKlO gLLcWv">
#                 <a class="sc-hCPjZK cfPxOX sc-xyOoZ fREXsT sc-xyOoZ fREXsT" color="text.lightest" data-testid="link-item" font-size="1" href="https://ri.magazineluiza.com.br/show.aspx?idCanal=Zkqmz6KAKUXGYIsGZCxxhg==" title="Link para: Assessoria de Imprensa">
#                  <span class="sc-dqJYEZ kDyRHs">
#                   <div class="sc-hMBXfw dsToUA">
#                    assessoria de imprensa
#                   </div>
#                  </span>
#                 </a>
#                </li>
#                <li class="sc-gPDKlO gLLcWv">
#                 <a class="sc-hCPjZK cfPxOX sc-xyOoZ fREXsT sc-xyOoZ fREXsT" color="text.lightest" data-testid="link-item" font-size="1" href="https://ri.magazineluiza.com.br/" title="Link para: Investidores">
#                  <span class="sc-dqJYEZ dUWTRX">
#                   <div class="sc-hMBXfw dsToUA">
#                    investidores
#                   </div>
#                  </span>
#                  <span class="sc-dqJYEZ dUWTRX">
#                   <img alt="Investidores" class="sc-eBMEME ggDvke sc-iEkSXm gHLoUF" data-testid="image" height="" loading="lazy" src="https://wx.mlcdn.com.br/site/desk/footer/flag-brasil.svg" width=""/>
#                  </span>
#                 </a>
#                </li>
#                <li class="sc-gPDKlO gLLcWv">
#                 <a class="sc-hCPjZK cfPxOX sc-xyOoZ fREXsT sc-xyOoZ fREXsT" color="text.lightest" data-testid="link-item" font-size="1" href="https://ri.magazineluiza.com.br/Default.aspx?idioma=enu&amp;linguagem=en#" title="Link para: Investors">
#                  <span class="sc-dqJYEZ dUWTRX">
#                   <div class="sc-hMBXfw dsToUA">
#                    investors
#                   </div>
#                  </span>
#                  <span class="sc-dqJYEZ dUWTRX">
#                   <img alt="Investors" class="sc-eBMEME ggDvke sc-iEkSXm gHLoUF" data-testid="image" height="" loading="lazy" src="https://wx.mlcdn.com.br/site/desk/footer/flag-usa.svg" width=""/>
#                  </span>
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div data-testid="link-section">
#               <p class="sc-kuCHnY irIKRI" color="text.lightest" font-size="1" font-weight="regular">
#                fornecedores
#               </p>
#               <ul class="sc-ctLLLr NIBoy">
#                <li class="sc-gPDKlO gLLcWv">
#                 <a class="sc-hCPjZK cfPxOX sc-xyOoZ fREXsT sc-xyOoZ fREXsT" color="text.lightest" data-testid="link-item" font-size="1" href="https://www.accesstage.com.br/PortalFinanceiro/login.jsf" title="Link para: Portal Financeiro">
#                  <span class="sc-dqJYEZ kDyRHs">
#                   <div class="sc-hMBXfw dsToUA">
#                    portal financeiro
#                   </div>
#                  </span>
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </li>
#             <li class="sc-fYKINB jfOySF" data-testid="link-column">
#              <p class="sc-kuCHnY irIKRI" color="text.lightest" font-size="1" font-weight="regular">
#               compre pelo telefone
#              </p>
#              <div class="sc-cZYOMl dRVXHS">
#               <div class="sc-bRimrq grIozW" color="text.lightest">
#                <p class="sc-dLmyTH ldVbLh" font-size="5">
#                 0800 773 3838
#                </p>
#                <div class="sc-bHxGWI cMUZSe" data-testid="sales-channels">
#                </div>
#                <p class="sc-fInFcU SANFt" font-size="0">
#                 segunda a sexta das 8 às 22h e sábados e domingos das 8 às 20h (exceto feriados)
#                </p>
#                <ul class="sc-hCrRFl eJDOvi">
#                 <li class="sc-kyDlHK gBRMzc">
#                  <a class="sc-hCPjZK hRfPXC sc-bdlOLf kwWYSb sc-bdlOLf kwWYSb" color="text.lightest" data-testid="link" font-size="1" href="https://atendimento.magazineluiza.com.br/hc/pt-br?open=chat_televendas" title="Link para: compre também pelo chat online">
#                   compre também pelo chat online
#                  </a>
#                 </li>
#                 <li class="sc-kyDlHK gBRMzc">
#                  <svg class="sc-eqUAAy gDBKFH" data-testid="AccessibilityIcon" fill="currentColor" viewbox="0 0 24 24">
#                   <path clip-rule="evenodd" d="M12 2C13.1 2 14 2.9 14 4C14 5.1 13.1 6 12 6C10.9 6 10 5.1 10 4C10 2.9 10.9 2 12 2ZM21 9H15V22H13V16H11V22H9V9H3V7H21V9Z" fill="currentColor" fill-rule="evenodd">
#                   </path>
#                  </svg>
#                  <a class="sc-hCPjZK hzvCPm sc-bdlOLf kwWYSb sc-bdlOLf kwWYSb" color="text.lightest" data-testid="link" font-size="1" href="https://especiais.magazineluiza.com.br/acessibilidade/" title="Use este link para baixar gratuitamente o app de tecnologia assistiva eSSENTIAL Accessibility para pessoas com deficiência física ou ativar o Hand Talk. Essa iniciativa é parte do comprometimento da Magazine Luiza em promover inclusão e diversidade.">
#                   acessibilidade
#                  </a>
#                 </li>
#                 <li class="sc-kyDlHK gBRMzc">
#                  <svg class="sc-eqUAAy gDBKFH" data-testid="CategoryTEIcon" fill="currentColor" viewbox="0 0 13 20">
#                   <path d="M11 0H2C1.46957 0 0.960888 0.210714 0.585815 0.585786C0.210743 0.960859 0 1.46957 0 2V18C0 18.5304 0.210743 19.0391 0.585815 19.4142C0.960888 19.7893 1.46957 20 2 20H11C11.5304 20 12.0392 19.7893 12.4142 19.4142C12.7893 19.0391 13 18.5304 13 18V2C13 1.46957 12.7893 0.960859 12.4142 0.585786C12.0392 0.210714 11.5304 0 11 0ZM4 1.5H9V2H4V1.5ZM6.5 18.5C6.25277 18.5 6.0111 18.4267 5.80554 18.2893C5.59998 18.152 5.43976 17.9568 5.34515 17.7284C5.25054 17.4999 5.22582 17.2486 5.27405 17.0061C5.32228 16.7637 5.44133 16.5409 5.61615 16.3661C5.79097 16.1913 6.01369 16.0722 6.25616 16.024C6.49864 15.9758 6.74999 16.0005 6.97839 16.0951C7.2068 16.1898 7.40202 16.35 7.53937 16.5555C7.67672 16.7611 7.75 17.0028 7.75 17.25C7.75 17.5815 7.61833 17.8995 7.38391 18.1339C7.14949 18.3683 6.83152 18.5 6.5 18.5ZM11 14.5H2V3.5H11V14.5Z" fill="currentColor">
#                   </path>
#                  </svg>
#                  <a class="sc-hCPjZK hzvCPm sc-bdlOLf kwWYSb sc-bdlOLf kwWYSb" color="text.lightest" data-testid="link" font-size="1" href="https://www.magazineluiza.com.br/redirect/mobile/" title="Link para: versão mobile">
#                   versão mobile
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#         <div class="sc-fYEEdK huJnnO">
#          <div class="sc-ioUWlN ijrbNp">
#           <p class="sc-kpDqfm giawfp sc-kypfzD eGvnX" color="#404040" data-testid="bottom-info-text-line" font-size="0">
#            Preços e condições de pagamento exclusivos para compras via internet, podendo variar nas lojas físicas. Ofertas válidas na compra de até 5 peças de cada produto por cliente, até o término dos nossos estoques para internet. Caso os produtos apresentem divergências de valores, o preço válido é o da sacola de compras.
#           </p>
#           <p class="sc-kpDqfm giawfp sc-kypfzD eGvnX" color="#404040" data-testid="bottom-info-text-line" font-size="0">
#            Vendas sujeitas a análise e confirmação de dados.
#           </p>
#           <p class="sc-kpDqfm giawfp sc-kypfzD eGvnX" color="#404040" data-testid="bottom-info-text-line" font-size="0">
#            O Magazine Luiza atua como correspondente no País, nos termos da Resolução CMN nº 4.935/2021, e encaminha propostas de cartão de crédito e operações de crédito para a Luizacred S.A Sociedade de Crédito, Financiamento e Investimento inscrita no CNPJ sob o nº 02.206.577/0001-80.
#           </p>
#           <p class="sc-kpDqfm giawfp sc-kypfzD eGvnX" color="#404040" data-testid="bottom-info-text-line" font-size="0">
#            Magazine Luiza S/A - CNPJ: 47.960.950/1088-36
#           </p>
#           <p class="sc-kpDqfm giawfp sc-kypfzD eGvnX" color="#404040" data-testid="bottom-info-text-line" font-size="0">
#            Endereço: Rua Arnulfo de Lima, 2385 - Vila Santa Cruz, Franca/SP - CEP 14.403-471
#           </p>
#           <p class="sc-kpDqfm giawfp sc-kypfzD eGvnX" color="#404040" data-testid="bottom-info-link-line" font-size="0">
#            ® Magazine Luiza – Todos os direitos reservados. Endereço eletrônico
#            <!-- -->
#            :
#            <a class="sc-bfUCjU dCmDwq" href="https://www.magazineluiza.com.br">
#             https://www.magazineluiza.com.br
#            </a>
#           </p>
#           <p class="sc-kpDqfm giawfp sc-kypfzD eGvnX" color="#404040" data-testid="bottom-info-link-line" font-size="0">
#            Fale conosco
#            <!-- -->
#            :
#            <a class="sc-bfUCjU dCmDwq" href="https://www.magazineluiza.com.br/central-de-atendimento/fale-conosco/">
#             https://www.magazineluiza.com.br/central-de-atendimento/fale-conosco/
#            </a>
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#      </section>
#     </main>
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{"data":{"allCategories":[{"__typename":"Category","meta":{"__typename":"MetaCategory","canonical":"https://www.magazineluiza.com.br/ar-e-ventilacao/l/ar/","breadcrumbAlias":"Ar e Ventilação","description":"As melhores ofertas de ar condicionado, ventiladores e climatizadores estão aqui no Magazine Luiza! Corre pra aproveitar os melhores preços e condições!","seoBlock":"\u003cp dir=\"ltr\"\u003e\u003cspan style=\"font-size: 12pt;\"\u003eO ar-condicionado \u0026eacute; o aparelho de \u003c/span\u003e\u003ca href=\"https://www.magazineluiza.com.br/ar-e-ventilacao/l/ar/\" target=\"_blank\" rel=\"noopener\"\u003e\u003cspan style=\"color: #1155cc; font-size: 12pt;\"\u003ear e ventila\u0026ccedil;\u0026atilde;o\u003c/span\u003e\u003c/a\u003e\u003cspan style=\"font-size: 12pt;\"\u003e\u0026nbsp; ideal pra deixar o ambiente mais agrad\u0026aacute;vel e na temperatura certinha, viu? Ele conta com vers\u0026otilde;es modernas frio ou quente-frio que mant\u0026eacute;m a casa climatizada tamb\u0026eacute;m no inverno, sabia? Pois \u0026eacute;! Vem comigo que eu te ajudo a acertar em cheio na escolha!\u003c/span\u003e\u003c/p\u003e\n\u003cp\u003e\u0026nbsp;\u003c/p\u003e"},"label":"Ar e Ventilação","id":"AR","description":"Ar e Ventilação"},{"__typename":"Category","meta":{"__typename":"MetaCategory","canonical":"https://www.magazineluiza.com.br/artesanato/l/am/","breadcrumbAlias":"Artesanato","description":"Artigos de Armarinhos, Artigos para festa e Produtos para Artesanato com os melhores preços você encontra aqui no Magazine Luiza! Clique e aproveite! ;)","seoBlock":"\u003cp dir=\"ltr\"\u003e\u003cspan style=\"font-size: 12pt;\"\u003eGente, o artesanato \u0026eacute; uma t\u0026eacute;cnica usada pra criar itens com as m\u0026atilde;os. E o legal \u0026eacute; que geralmente \u0026eacute; indicado pra quem quer ter um novo passatempo pra quebrar a rotina ou tamb\u0026eacute;m uma fonte de renda extra. Como d\u0026aacute; pra fazer diferentes coisas com v\u0026aacute;rios materiais, fica f\u0026aacute;cil achar aquele que mais combina com voc\u0026ecirc;. Quer saber os detalhes? Vem comigo que eu te mostro:\u003c/span\u003e\u003c/p\u003e\n\u003cp\u003e\u0026nbsp;\u003c/p\u003e"},"label":"Artesanato","id":"AM","description":"Artesanato"},{"__typename":"Category","meta":{"__typename":"MetaCategory","canonical":"https://www.magazineluiza.com.br/artigos-para-festa/l/af/","breadcrumbAlias":"Artigos para Festa","description":"","seoBlock":"\u003cp\u003e\u003cspan style=\"font-size: 12pt;\"\u003eGente, os artigos de festa s\u0026atilde;o itens e acess\u0026oacute;rios pra usar na \u003c/span\u003e\u003ca href=\"https://www.magazineluiza.com.br/decoracao/l/de/\" target=\"_blank\" rel=\"noopener\"\u003e\u003cspan style=\"color: #1155cc; font-size: 12pt;\"\u003edecora\u0026ccedil;\u0026atilde;o\u003c/span\u003e\u003c/a\u003e\u003cspan style=\"font-size: 12pt;\"\u003e, viu? Pra isso, voc\u0026ecirc; encontra diferentes op\u0026ccedil;\u0026otilde;es como \u003c/span\u003e\u003ca href=\"https://www.magazineluiza.com.br/baloes-e-acessorios/artigos-para-festa/s/af/balo/\" target=\"_blank\" rel=\"noopener\"\u003e\u003cspan style=\"color: #1155cc; font-size: 12pt;\"\u003ebal\u0026otilde;es\u003c/span\u003e\u003c/a\u003e\u003cspan style=\"font-size: 12pt;\"\u003e, \u003c/span\u003e\u003ca href=\"https://www.magazineluiza.com.br/aderecos-para-festa/artigos-para-festa/s/af/adpf/\" target=\"_blank\" rel=\"noopener\"\u003e\u003cspan style=\"color: #1155cc; font-size: 12pt;\"\u003eadere\u0026ccedil;os\u003c/span\u003e\u003c/a\u003e\u003cspan style=\"font-size: 12pt;\"\u003e, \u003c/span\u003e\u003ca href=\"https://www.magazineluiza.com.br/copo/artigos-para-festa/s/af/cpda/\" target=\"_blank\" rel=\"noopener\"\u003e\u003cspan style=\"color: #1155cc; font-size: 12pt;\"\u003ecopos\u003c/span\u003e\u003c/a\u003e\u003cspan style=\"font-size: 12pt;\"\u003e, \u003c/span\u003e\u003ca href=\"https://www.magazineluiza.com.br/prato-descartave ...
#   </script>
#  </body>
# </html>

# %%
items = soup.find_all("li", attrs={"class" : "sc-CCtys ddCamx"})


for item in items:
    div = item.find_all('div', class_='sc-eWHaVC eAnweT')
    print(div)

# %%
items = soup.find_all('li', attrs={"class": "sc-CCtys ddCamx"})

for item in items:
    specific_divs = item.find_all('div', attrs={"class": 'sc-eWHaVC eAnweT'})
    for specific_div in specific_divs:
        h2_tag = specific_div.find('h2')
        if h2_tag:
            print(h2_tag.get_text())
# Out:
# Geladeira Brastemp Frost Free Duplex 375L Inox com
# Geladeira/Refrigerador Consul Frost Free Duplex Branco 386L CRM44AB
# Geladeira/Refrigerador Electrolux Frost Free
# Geladeira/Refrigerador Electrolux Degelo Manual Duplex 260L Cycle Defrost DC35A Branco
# Geladeira/Refrigerador Esmaltec Cycle Defrost
# Geladeira/Refrigerador Consul Frost Free Duplex
# Geladeira/Refrigerador Consul Frost Free
# Geladeira/Refrigerador Electrolux Frost Free
# Geladeira/Refrigerador Electrolux 240L RE31 Branco
# Geladeira Brastemp Frost Free Duplex 375L Branca com
# Geladeira/Refrigerador Panasonic Frost Free Duplex 387L Top Freezer BT41X
# Geladeira Electrolux Frost Free 310L Duplex Branca (TF39)
# Geladeira Electrolux Frost Free 310L Duplex Cor Inox (TF39S)
# Geladeira/Refrigerador Electrolux Frost Free
# Geladeira/Refrigerador Brastemp Frost Free Duplex Prata 447L BRE57FK
# Geladeira Consul Frost Free Duplex 386 litros com Altura Flex cor branca CRM44AB
# Geladeira/Refrigerador Electrolux Frost Free
# Geladeira/Refrigerador Electrolux Frost Free Multidoor
# Geladeira/Refrigerador Brastemp Frost Free French Door 554L BRO85
# Geladeira Cycle Defrost Electrolux 240 Litros Degelo Prático Branco RE31 - 110V
# Geladeira/Refrigerador Consul Frost Free Duplex
# Geladeira/Refrigerador Consul Frost Free Duplex
# Geladeira/Refrigerador Electrolux Frost Free
# Geladeira/Refrigerador Midea Frost Free Duplex
# Geladeira Brastemp Frost Free Duplex 375 litros cor Inox com Espaço Adapt - BRM45JK
# Geladeira Brastemp Frost Free Inverse 588 litros cor Inox com Smart Bar BRE85AK
# Geladeira/Refrigerador Panasonic Frost Free Duplex
# Geladeira/Refrigerador Panasonic Frost Free I
# Geladeira Consul Frost Free Duplex 386 litros com Altura Flex cor Inox CRM44AK
# Geladeira Consul Frost Free Duplex 340 litros Branca com Prateleiras Altura Flex - CRM39AB
# Geladeira Consul 1 Porta Frost Free 300 Litros CRB36ABANA
# Geladeira/Refrigerador Brastemp Frost Free Duplex 447L BRE57FB
# Geladeira/Refrigerador Consul Cycle Defrost Duplex
# Geladeira/Refrigerador Brastemp Frost Free Duplex
# Geladeira Electrolux Frost Free Inverter 488L Experience Fresh&Flex Inverse Branca (IB55)
# Geladeira/Refrigerador Electrolux Frost Free
# Geladeira Electrolux Frost Free Inverter 409L Água na Porta AutoSense cor Inox Look (IW45S)
# Geladeira/Refrigerador Panasonic Frost Free I
# Geladeira Consul Frost Free 342 litros cor Inox com Gavetão Hortifruti - CRB39AK
# Geladeira / Refrigerador Brastemp 375 Litros 2 Portas Frost Free BRM44HB
# Geladeira Consul Frost Free Duplex com Espaço Flex e Painel Eletrônico Externo 451 litros cor Inox - CRM56FK
# Geladeira/Refrigerador Electrolux Frost Free
# Geladeira Brastemp Frost Free Inverse A+++ 479 litros cor Inox com Super Capacidade e Smart Flow - BRE58FK
# Geladeira/Refrigerador Continental Frost Free
# Geladeira Consul Cycle Defrost Duplex 334 litros Branca com Freezer Supercapacidade - CRD37EB
# Geladeira/Refrigerador Electrolux Frost Free
# Geladeira Frost Free Duplex 347L SmartSensor Cor Prata Midea
# Geladeira/Refrigerador LG Frost Free Duplex 395L
# Geladeira Consul Frost Free Duplex 386 litros com Altura Flex cor Inox CRM44AK
# Geladeira/Refrigerador Esmaltec Degelo Manual 1 Porta Branca 259L Roc35 Pro
# Geladeira Consul Frost Free Duplex com Espaço Flex e Painel Eletrônico Externo 451 litros cor Branca - CRM56FB
# Geladeira/Refrigerador Consul Frost Free Duplex Evox 340L CRM39 AKANA
# Geladeira/Refrigerador Electrolux Frost Free
# Geladeira Electrolux Frost Free Inverter 431L AutoSense Duplex Cor Black Inox Look (IF55B)
# Geladeira/Refrigerador Electrolux Frost Free
# Geladeira Electrolux Frost Free Duplex Preta 480L Efficient IT70B B
# Geladeira/Refrigerador Continental Frost Free
# Geladeira Electrolux Frost Free Inverter 390L Efficient AutoSense Duplex Black Inox Look (IF43B)
# Geladeira Refrigerador Electrolux Frost Free Duplex 371L DFN41
# Geladeira/Refrigerador Consul Frost Free

# %%
import json


data = []
items = soup.find_all('li', attrs={"class": "sc-CCtys ddCamx"})

for item in items:
    specific_divs = item.find_all('div', attrs={"class": 'sc-eWHaVC eAnweT'})
    for specific_div in specific_divs:
        price_tag = specific_div.find('div', attrs={"class": 'sc-fqkvVR hlqElk sc-hoLEA cHBAPg'})
        if price_tag:
            print(price_tag.p.get_text())
            data.append({"Price" : price_tag.p.get_text()})
            data.append({"Price" : price_tag.p.get_text()})

with open('data.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)
# Out:
# R$ 4.270,00
# R$ 3.455,86
# R$ 4.479,00
# R$ 2.799,00
# R$ 2.599,00
# R$ 3.999,00
# R$ 3.599,00
# R$ 5.269,00
# R$ 2.599,00
# R$ 3.710,00
# R$ 5.199,00
# R$ 3.489,00
# R$ 4.039,00
# R$ 3.879,00
# R$ 5.599,00
# R$ 4.449,00
# R$ 4.340,00
# R$ 8.299,00
# R$ 8.503,32
# R$ 1.954,44
# R$ 4.299,00
# R$ 3.999,00
# R$ 4.759,00
# R$ 3.719,20
# R$ 3.999,00
# R$ 8.799,00
# R$ 4.199,00
# R$ 4.499,00
# R$ 4.999,00
# R$ 4.709,00
# R$ 2.278,00
# R$ 4.999,00
# R$ 2.999,00
# R$ 7.699,00
# R$ 6.359,00
# R$ 3.879,00
# R$ 4.799,00
# R$ 5.199,00
# R$ 4.099,00
# R$ 3.221,11
# R$ 3.999,00
# R$ 4.529,90
# R$ 5.099,00
# R$ 3.290,00
# R$ 3.979,00
# R$ 5.029,90
# R$ 3.099,00
# R$ 4.380,02
# R$ 4.999,00
# R$ 2.705,00
# R$ 3.749,00
# R$ 3.570,00
# R$ 6.563,10
# R$ 5.899,00
# R$ 4.738,66
# R$ 5.299,00
# R$ 3.850,00
# R$ 4.299,00
# R$ 3.399,90
# R$ 3.080,00
